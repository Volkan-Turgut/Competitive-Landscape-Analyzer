# %% [markdown]
# # Init

# %% [markdown]
# ## Installs

# %%
# !pip install -q pydantic-ai tavily-python fastapi uvicorn httpx

# %% [markdown]
# ## API Keys

# %%
print("import completed")

# %%
import os

os.environ["ANTHROPIC_API_KEY"] = "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"
os.environ["TAVILY_API_KEY"] = "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"
print("import completed")

# %% [markdown]
# ## Modules

# %%
from pydantic_ai import Agent, RunContext
from pydantic import BaseModel
from tavily import TavilyClient
import asyncio
import os

# %% [markdown]
# # Agents

# %% [markdown]
# ## Agent Architecture Overview
#
# This notebook implements a multi-agent competitive intelligence system with four specialized agents:
#
# 1. **Incumbents Agent** — Identifies established players in the target market, their positioning, product offerings, market share estimates, and barriers to entry.
#
# 2. **Emerging Competitors Agent** — Discovers startups, recent funding activity (Seed through Series B), new entrants, and the velocity of capital flowing into the space.
#
# 3. **Market Sizing Agent** — Performs quantitative analysis including TAM/SAM, growth projections, and supporting data from industry sources (Gartner, Forrester, Statista, etc.).
#
# 4. **Synthesis Agent** — Cross-references findings from all three research agents to evaluate white space and deliver a **Go/No-Go** recommendation with reasoning.
#
# Each agent uses **Tavily** web search as a tool and returns structured **Pydantic** model outputs.

# %% [markdown]
# ## Incumbents Agent

# %%
import sys

# --- Output Models ---
print("[1/6] Defining output models...")
sys.stdout.flush()

class Competitor(BaseModel):
    name: str
    description: str
    market_position: str
    key_products: list[str]
    strengths: list[str]
    weaknesses: list[str]
    estimated_market_share: str | None = None

class IncumbentsResult(BaseModel):
    competitors: list[Competitor]
    market_overview: str
    concentration_level: str  # "high", "moderate", "fragmented"
    key_trends: list[str]
    barriers_to_entry: list[str]

print("[1/6] ✅ Models defined")
sys.stdout.flush()

# --- Agent Definition ---
print("[2/6] Creating agent...")
sys.stdout.flush()

incumbents_agent = Agent(
    model="anthropic:claude-sonnet-4-6",
    output_type=IncumbentsResult,
    retries=1,
    system_prompt=(
        "You are a competitive intelligence analyst specializing in identifying "
        "established players in a given market.\n\n"
        "When given a company and market space, use web search to thoroughly research:\n"
        "- Major incumbents (top 5-8) and their market positioning\n"
        "- Each competitor's core product offerings and differentiation\n"
        "- Estimated market share where available\n"
        "- Strengths and weaknesses of each player\n"
        "- Overall market concentration and barriers to entry\n\n"
        "Search strategy:\n"
        "1. First search for '[market] market leaders' and '[market] competitive landscape'\n"
        "2. Then search for specific companies found to get deeper detail\n"
        "3. Search for '[market] market share' for quantitative data\n"
        "4. Search for '[market] barriers to entry'\n\n"
        "IMPORTANT: Limit yourself to at most 5 search queries total.\n"
        "Be data-driven. Cite specific companies, products, and figures. "
        "Do not fabricate market share numbers — if unavailable, say so."
    ),
)

print("[2/6] ✅ Agent created")
sys.stdout.flush()

# --- Search Tool ---
print("[3/6] Registering search tool...")
sys.stdout.flush()

@incumbents_agent.tool_plain
def search_web(query: str) -> str:
    """Search the web for competitive intelligence information.

    Args:
        query: The search query to find market and competitor data.
    """
    print(f"  🔍 Searching: {query}")
    sys.stdout.flush()
    client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
    response = client.search(query, search_depth="advanced", max_results=5)
    results = []
    for r in response["results"]:
        results.append(f"Title: {r['title']}\nURL: {r['url']}\nContent: {r['content']}")
    print(f"  ✅ Got {len(results)} results")
    sys.stdout.flush()
    return "\n\n---\n\n".join(results)

print("[3/6] ✅ Tool registered")
sys.stdout.flush()

# --- Test Call ---
print("[4/6] Starting agent run (this may take 30-60s)...")
print("       Calling: company=Salesforce, market=AI code review")
sys.stdout.flush()

result = await incumbents_agent.run(
    "Find the major established competitors for Salesforce in the AI code review market"
)

print("[5/6] ✅ Agent run complete!")
sys.stdout.flush()

# --- Display Results ---
print("[6/6] Displaying results...\n")
sys.stdout.flush()

print("=" * 60)
print("RESULTS")
print("=" * 60)

for c in result.output.competitors:
    print(f"\n{'─'*50}")
    print(f"  {c.name} — {c.market_position}")
    print(f"  Products: {', '.join(c.key_products)}")
    print(f"  Market Share: {c.estimated_market_share or 'N/A'}")

print(f"\n{'─'*50}")
print(f"Market Overview: {result.output.market_overview}")
print(f"Concentration: {result.output.concentration_level}")
print(f"Barriers: {', '.join(result.output.barriers_to_entry)}")
sys.stdout.flush()

# %%
print("Kernel is alive and producing output!")
